# %%
import os 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#chargement du dataset

data_frame = pd.read_csv('/Users/bakarybengaly/Documents/AnalyseventesB2B/dataset techsales360.csv')
data_frame.head()
# Out:
#   transaction_id client_id commercial_id date_transaction  \
# 0      TXN-00001  CLI-6104       COM-149       2021-08-17
# 1      TXN-00002  CLI-3646       COM-136       2021-02-21
# 2      TXN-00003  CLI-1633       COM-102       2022-07-18
# 3      TXN-00004  CLI-3466       COM-107       2022-05-17
# 4      TXN-00005  CLI-9677       COM-135       2022-04-03
#
#                  region                 ville segment_client  age_client  \
# 0  Auvergne-Rhône-Alpes              Grenoble            TPE          58
# 1             Normandie                 Rouen            TPE          37
# 2       Hauts-de-France               Roubaix    Particulier          28
# 3             Occitanie           Montpellier            PME          39
# 4         Île-de-France  Boulogne-Billancourt    Particulier          31
#
#    anciennete_client_annees   canal_acquisition  ... nb_contacts_avant_vente  \
# 0                         3  Commercial Terrain  ...                       1
# ...

# %%
#visualisation des types des données 
data_frame.dtypes
# Out:
# transaction_id               object
# client_id                    object
# commercial_id                object
# date_transaction             object
# region                       object
# ville                        object
# segment_client               object
# age_client                    int64
# anciennete_client_annees      int64
# canal_acquisition            object
# campagne_marketing           object
# cout_acquisition_eur        float64
# categorie_produit            object
# produit                      object
# nb_licences                   int64
# montant_brut_eur            float64
# remise_pct                  float64
# montant_net_eur             float64
# nb_contacts_avant_vente       int64
# duree_cycle_vente_jours       int64
# taux_conversion_pct         float64
# score_satisfaction          float64
# nps_score                     int64
# taux_utilisation_pct        float64
# nb_tickets_support            int64
# uptime_pct                  float64
# ...

# %%
#visualisation des types des données 
data_frame.dtypes
# Out:
# transaction_id               object
# client_id                    object
# commercial_id                object
# date_transaction             object
# region                       object
# ville                        object
# segment_client               object
# age_client                    int64
# anciennete_client_annees      int64
# canal_acquisition            object
# campagne_marketing           object
# cout_acquisition_eur        float64
# categorie_produit            object
# produit                      object
# nb_licences                   int64
# montant_brut_eur            float64
# remise_pct                  float64
# montant_net_eur             float64
# nb_contacts_avant_vente       int64
# duree_cycle_vente_jours       int64
# taux_conversion_pct         float64
# score_satisfaction          float64
# nps_score                     int64
# taux_utilisation_pct        float64
# nb_tickets_support            int64
# uptime_pct                  float64
# ...

# %%
#changement du type de la date d'objet en datetime
data_frame['date_transaction'] = pd.to_datetime(data_frame['date_transaction'])
data_frame.dtypes
# Out:
# transaction_id                      object
# client_id                           object
# commercial_id                       object
# date_transaction            datetime64[ns]
# region                              object
# ville                               object
# segment_client                      object
# age_client                           int64
# anciennete_client_annees             int64
# canal_acquisition                   object
# campagne_marketing                  object
# cout_acquisition_eur               float64
# categorie_produit                   object
# produit                             object
# nb_licences                          int64
# montant_brut_eur                   float64
# remise_pct                         float64
# montant_net_eur                    float64
# nb_contacts_avant_vente              int64
# duree_cycle_vente_jours              int64
# taux_conversion_pct                float64
# score_satisfaction                 float64
# ...

# %%
#visualisation des valeurs manquantes 
data_frame.isnull().sum()
# Out:
# transaction_id                0
# client_id                     0
# commercial_id                 0
# date_transaction              0
# region                        0
# ville                         0
# segment_client                0
# age_client                    0
# anciennete_client_annees      0
# canal_acquisition             0
# campagne_marketing          608
# cout_acquisition_eur          0
# categorie_produit             0
# produit                       0
# nb_licences                   0
# montant_brut_eur              0
# remise_pct                    0
# montant_net_eur               0
# nb_contacts_avant_vente       0
# duree_cycle_vente_jours       0
# taux_conversion_pct           0
# score_satisfaction            0
# nps_score                     0
# taux_utilisation_pct          0
# nb_tickets_support            0
# uptime_pct                    0
# churn                         0
# statut_renouvellement         0
# dtype: int64

# %%
#remplacements des valeurs manquantes par "aucune"
data_frame['campagne_marketing'] = data_frame['campagne_marketing'].fillna('aucune')
data_frame.isnull().sum()
# Out:
# transaction_id              0
# client_id                   0
# commercial_id               0
# date_transaction            0
# region                      0
# ville                       0
# segment_client              0
# age_client                  0
# anciennete_client_annees    0
# canal_acquisition           0
# campagne_marketing          0
# cout_acquisition_eur        0
# categorie_produit           0
# produit                     0
# nb_licences                 0
# montant_brut_eur            0
# remise_pct                  0
# montant_net_eur             0
# nb_contacts_avant_vente     0
# duree_cycle_vente_jours     0
# taux_conversion_pct         0
# score_satisfaction          0
# nps_score                   0
# taux_utilisation_pct        0
# nb_tickets_support          0
# uptime_pct                  0
# churn                       0
# statut_renouvellement       0
# dtype: int64

# %%
# statistique descriptive 
data_frame.describe()
# Out:
#                  date_transaction  age_client  anciennete_client_annees  \
# count                        5000   5000.0000               5000.000000
# mean   2022-07-05 22:42:31.680000     38.0058                  2.550000
# min           2021-01-01 00:00:00     18.0000                  0.000000
# 25%           2021-10-05 00:00:00     30.0000                  0.000000
# 50%           2022-07-07 12:00:00     38.0000                  2.000000
# 75%           2023-04-01 00:00:00     46.0000                  4.000000
# max           2024-01-01 00:00:00     75.0000                 15.000000
# std                           NaN     11.5135                  2.920138
#
#        cout_acquisition_eur  nb_licences  montant_brut_eur   remise_pct  \
# count           5000.000000  5000.000000       5000.000000  5000.000000
# mean             208.421212    39.723600       6310.947212     7.879340
# min                0.000000     1.000000        103.460000     0.100000
# ...

# %%
#creation de colonnes (Marge, roi)
data_frame['marge_eur'] = data_frame['montant_net_eur'] - data_frame['cout_acquisition_eur']
data_frame['marge_eur']
# Out:
# 0       -2517.90
# 1       -3811.42
# 2       -2126.90
# 3       -7674.66
# 4       -1862.72
#           ...
# 4995    -2370.95
# 4996    -1992.12
# 4997    -1046.82
# 4998    -1631.66
# 4999   -15958.93
# Name: marge_eur, Length: 5000, dtype: float64

# %%
data_frame['annee'] = data_frame['date_transaction'].dt.year
data_frame['mois']  = data_frame['date_transaction'].dt.month

# %%
#voir les tendance et la saisonnalité
ca_annee_mois = data_frame.groupby(['annee', 'mois'])['montant_net_eur'].sum().reset_index()
ca_annee = data_frame.groupby('annee')['montant_net_eur'].sum()

# Labels et couleurs
mois_labels = ['Jan','Fév','Mar','Avr','Mai','Jun','Jul','Aoû','Sep','Oct','Nov','Déc']
colors = ['#2196F3', '#4CAF50', '#FF9800']

import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

# Groupby
ca_annee_mois = data_frame.groupby(['annee', 'mois'])['montant_net_eur'].sum().reset_index()

# Labels et couleurs
mois_labels = ['Jan','Fév','Mar','Avr','Mai','Jun','Jul','Aoû','Sep','Oct','Nov','Déc']
colors = ['#2196F3', '#4CAF50', '#FF9800']

# Figure + axe
fig, ax1 = plt.subplots(figsize=(15, 5))
fig.suptitle("Évolution du Chiffre d'Affaires", fontsize=16, fontweight='bold', y=0.98)

# Graphique
for i, annee in enumerate([2021, 2022, 2023]):
    data = ca_annee_mois[ca_annee_mois['annee'] == annee]
    ax1.plot(data['mois'], data['montant_net_eur'],
             marker='o', label=str(annee),
             color=colors[i], linewidth=2.5)

# Mise en forme
ax1.set_title("CA mensuel par année (2021–2023)", fontsize=13)
ax1.set_xticks(range(1, 13))
ax1.set_xticklabels(mois_labels)
ax1.yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'{x/1e6:.2f}M€'))
ax1.legend()
ax1.grid(True, alpha=0.3)
ax1.set_ylabel("Chiffre d'affaires")

plt.show()

# %%
#voir les tendance et la saisonnalité
ca_annee_mois = data_frame.groupby(['annee', 'mois'])['montant_net_eur'].sum().reset_index()
ca_annee = data_frame.groupby('annee')['montant_net_eur'].sum()

# Labels et couleurs
mois_labels = ['Jan','Fév','Mar','Avr','Mai','Jun','Jul','Aoû','Sep','Oct','Nov','Déc']
colors = ['#2196F3', '#4CAF50', '#FF9800']

import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

# Groupby
ca_annee_mois = data_frame.groupby(['annee', 'mois'])['montant_net_eur'].sum().reset_index()

# Labels et couleurs
mois_labels = ['Jan','Fév','Mar','Avr','Mai','Jun','Jul','Aoû','Sep','Oct','Nov','Déc']
colors = ['#2196F3', '#4CAF50', '#FF9800']

# Figure + axe
fig, ax1 = plt.subplots(figsize=(15, 5))
fig.suptitle("Évolution du Chiffre d'Affaires", fontsize=16, fontweight='bold', y=0.98)

# Graphique
for i, annee in enumerate([2021, 2022, 2023]):
    data = ca_annee_mois[ca_annee_mois['annee'] == annee]
    ax1.plot(data['mois'], data['montant_net_eur'],
             marker='o', label=str(annee),
             color=colors[i], linewidth=2.5)

# Mise en forme
ax1.set_title("CA mensuel par année (2021–2023)", fontsize=13)
ax1.set_xticks(range(1, 13))
ax1.set_xticklabels(mois_labels)
ax1.yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'{x/1e6:.2f}M€'))
ax1.legend()
ax1.grid(True, alpha=0.3)
ax1.set_ylabel("Chiffre d'affaires")

plt.show()

# %%
#voir les tendance et la saisonnalité
ca_annee_mois = data_frame.groupby(['annee', 'mois'])['montant_net_eur'].sum().reset_index()
ca_annee = data_frame.groupby('annee')['montant_net_eur'].sum()

# Labels et couleurs
mois_labels = ['Jan','Fév','Mar','Avr','Mai','Jun','Jul','Aoû','Sep','Oct','Nov','Déc']
colors = ['#2196F3', '#4CAF50', '#FF9800']

import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

# Groupby
ca_annee_mois = data_frame.groupby(['annee', 'mois'])['montant_net_eur'].sum().reset_index()

# Labels et couleurs
mois_labels = ['Jan','Fév','Mar','Avr','Mai','Jun','Jul','Aoû','Sep','Oct','Nov','Déc']
colors = ['#2196F3', '#4CAF50', '#FF9800']

# Figure + axe
fig, ax1 = plt.subplots(figsize=(15, 5))
fig.suptitle("Évolution du Chiffre d'Affaires", fontsize=16, fontweight='bold', y=0.98)

# Graphique
for i, annee in enumerate([2021, 2022, 2023]):
    data = ca_annee_mois[ca_annee_mois['annee'] == annee]
    ax1.plot(data['mois'], data['montant_net_eur'],
             marker='o', label=str(annee),
             color=colors[i], linewidth=2.5)

# Mise en forme
ax1.set_title("CA mensuel par année (2021–2023)", fontsize=13)
ax1.set_xticks(range(1, 13))
ax1.set_xticklabels(mois_labels)
ax1.yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'{x/1e6:.2f}M€'))
ax1.legend()
ax1.grid(True, alpha=0.3)
ax1.set_ylabel("Chiffre d'affaires")

plt.show()

# %%
ca_annee_mois = data_frame.groupby(['annee', 'mois'])['montant_net_eur'].sum().reset_index()

# Labels et couleurs
mois_labels = ['Jan','Fév','Mar','Avr','Mai','Jun','Jul','Aoû','Sep','Oct','Nov','Déc']
colors = ['#2196F3', '#4CAF50', '#FF9800']

# Graphique
fig, ax = plt.subplots(figsize=(12, 5))
ax.set_title("CA mensuel par année (2021–2023)", fontsize=14, fontweight='bold')

for i, annee in enumerate([2021, 2022, 2023]):
    data = ca_annee_mois[ca_annee_mois['annee'] == annee]
    ax.plot(data['mois'], data['montant_net_eur'],
            marker='o', label=str(annee),
            color=colors[i], linewidth=2.5)

ax.set_xticks(range(1, 13))
ax.set_xticklabels(mois_labels)
ax.yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'{x/1e6:.2f}M€'))
ax.legend()
ax.grid(True, alpha=0.3)
ax.set_ylabel("Chiffre d'affaires")

plt.tight_layout()
plt.show()

# %%
#chiffre d'affaire par region

ca_par_region = data_frame.groupby('region')['montant_net_eur'].sum().sort_values()

plt.figure(figsize=(9, 5))
plt.barh(ca_par_region.index, ca_par_region.values,
         color='steelblue', edgecolor='white')

for i, val in enumerate(ca_par_region.values):
    plt.text(val + 30000, i, f'{val/1e6:.1f}M€', va='center', fontsize=9)

plt.title("CA total par région", fontsize=14, fontweight='bold')
plt.xlabel("CA net (€)")
plt.tight_layout()
plt.show()

# %%
# CA par catégorie produit
ca_par_categorie = data_frame.groupby('categorie_produit')['montant_net_eur'].sum().sort_values()

plt.figure(figsize=(9, 5))
plt.barh(ca_par_categorie.index, ca_par_categorie.values,
         color='mediumseagreen', edgecolor='white')

for i, val in enumerate(ca_par_categorie.values):
    plt.text(val + 30000, i, f'{val/1e6:.1f}M€', va='center', fontsize=9)

plt.title("CA total par catégorie produit", fontsize=14, fontweight='bold')
plt.xlabel("CA net (€)")
plt.tight_layout()
plt.show()

# %%
# CA par canal d'acquisition
ca_par_canal = data_frame.groupby('canal_acquisition')['montant_net_eur'].sum().sort_values()

plt.figure(figsize=(9, 5))
plt.barh(ca_par_canal.index, ca_par_canal.values,
         color='steelblue', edgecolor='white')

for i, val in enumerate(ca_par_canal.values):
    plt.text(val + 30000, i, f'{val/1e6:.1f}M€', va='center', fontsize=9)

plt.title("CA total par canal d'acquisition", fontsize=14, fontweight='bold')
plt.xlabel("CA net (€)")
plt.tight_layout()
plt.show()
